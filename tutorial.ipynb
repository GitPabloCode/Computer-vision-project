# %%
import numpy as np
from src.io.psee_loader import PSEELoader

# %% [markdown]
# # Opening a file

# %%
# open a file
video = PSEELoader("train_a/detection_dataset_duration_60s_ratio_1.0/train/17-03-30_12-53-58_183500000_243500000_td.dat")
print(video)  # show some metadata
video.event_count()  # number of events in the file
video.total_time()  # duration of the file in mus
# Out:
# PSEELoader:
# -----------
# Event Type: Event2D
# Event Size: 8 bytes
# Event Count: 76834655
# Duration: 59.999998 s
# -----------
# 59999998

# %% [markdown]
# # Event Format

# %%
# let's read some Events , there are two ways by number of events or by time slices
events = video.load_n_events(10)  # this loads the 10 next events
events
# Out:
# array([(28097212, 247, 193, 0), (28097212, 156, 207, 1),
#        (28097213,   9, 202, 1), (28097213, 301, 161, 1),
#        (28097213, 300, 161, 1), (28097214, 302, 161, 1),
#        (28097214, 303, 161, 1), (28097214, 297, 161, 1),
#        (28097214, 298, 161, 1), (28097214, 299, 161, 1)],
#       dtype=[('t', '<u4'), ('x', '<u2'), ('y', '<u2'), ('p', 'u1')])

# %% [markdown]
# Events are in a numpy [structured array](https://docs.scipy.org/doc/numpy/user/basics.rec.html)

# %%
# TLDR : we can access different fields in this one dimensional array
print(events['t'])  # this shows only the timestamps of events
# for instance to count the events of positive polarity you can do :
np.sum(events['p'] > 0)
# Out:
# [59999997 59999994 59999978 ... 59900009 59900007 59900007]
# 38369

# %%
# let's randomly drop some events
np.random.choice(events, len(events)//2)
# Out:
# array([( 9,  96, 113, 0), (12, 156, 138, 0), (11,  17, 130, 0),
#        (12, 156, 138, 0), (12, 156, 138, 0)],
#       dtype=[('t', '<u4'), ('x', '<u2'), ('y', '<u2'), ('p', 'u1')])

# %%
# let's now try to read 10ms worth of events
events = video.load_delta_t(10000)
events
# Out:
# array([(   13,  86,  68, 0), (   15, 224, 231, 1), (   16, 230, 224, 1),
#        ..., (10012, 262, 195, 1), (10012,   1, 195, 1),
#        (10012,  24, 170, 1)],
#       dtype=[('t', '<u4'), ('x', '<u2'), ('y', '<u2'), ('p', 'u1')])

# %% [markdown]
# # Iteration

# %%
# to iterate through a dataset you can use :
while not video.done:
    # load events and boxes from all files
    events = video.load_delta_t(50000)
    # do something with the events

# %%
# once a video is fully read there is no events in it anymore :
print(len(video.load_n_events(1)))
# Out:
# 0

# %%
# but you can rewind using seek_event or seek_time
video.seek_event(3)  # this goes before the fourth events (index starts at 0)

# %%
video.seek_time(10000)  # this goes before the first event after 9999mus

# %% [markdown]
# # Bonus

# %%
# this functions can be used to read a video backwards for instance
video.seek_time(video.total_time()+1)
delta_t = 100000
for t in np.arange(video.total_time()- delta_t, -delta_t, -delta_t):
    video.seek_time(t)
    events = video.load_delta_t(delta_t)
    # they should be sorted in descending timestamp order !
    events = events[::-1]
    print(events[0])
    print('timestamp', events[0]['t'])
    print('ascissa', events[0]['x'])
    print('ordinata', events[0]['y'])
    print('polarity', events[0]['p'])
    #break
    # do some cunning computer vision here.
    pass
# Out:
# (59999997, 19, 222, 0)
# timestamp 59999997
# ascissa 19
# ordinata 222
# polarity 0
# (59899982, 242, 140, 0)
# timestamp 59899982
# ascissa 242
# ordinata 140
# polarity 0
# (59799997, 273, 95, 0)
# timestamp 59799997
# ascissa 273
# ordinata 95
# polarity 0
# (59699996, 300, 114, 0)
# timestamp 59699996
# ascissa 300
# ordinata 114
# polarity 0
# (59599997, 15, 96, 0)
# timestamp 59599997
# ascissa 15
# ordinata 96
# polarity 0
# (59499995, 143, 100, 1)
# timestamp 59499995
# ascissa 143
# ordinata 100
# polarity 1
# (59399997, 277, 126, 1)
# timestamp 59399997
# ascissa 277
# ordinata 126
# polarity 1
# (59299996, 46, 112, 0)
# timestamp 59299996
# ascissa 46
# ordinata 112
# polarity 0
# (59199978, 7, 163, 1)
# timestamp 59199978
# ascissa 7
# ordinata 163
# polarity 1
# (59099997, 275, 11, 1)
# timestamp 59099997
# ascissa 275
# ordinata 11
# polarity 1
# (58999996, 186, 59, 0)
# timestamp 58999996
# ascissa 186
# ordinata 59
# polarity 0
# (58899997, 203, 201, 0)
# timestamp 58899997
# ascissa 203
# ordinata 201
# polarity 0
# (58799994, 71, 30, 1)
# timestamp 58799994
# ascissa 71
# ordinata 30
# polarity 1
# (58699994, 176, 165, 0)
# timestamp 58699994
# ascissa 176
# ordinata 165
# polarity 0
# (58599995, 210, 198, 1)
# timestamp 58599995
# ascissa 210
# ordinata 198
# polarity 1
# (58499997, 256, 87, 0)
# timestamp 58499997
# ascissa 256
# ordinata 87
# polarity 0
# (58399997, 240, 129, 0)
# timestamp 58399997
# ascissa 240
# ordinata 129
# polarity 0
# (58299979, 296, 140, 1)
# timestamp 58299979
# ascissa 296
# ordinata 140
# polarity 1
# (58199996, 170, 150, 0)
# timestamp 58199996
# ascissa 170
# ordinata 150
# polarity 0
# (58099993, 288, 13, 0)
# timestamp 58099993
# ascissa 288
# ordinata 13
# polarity 0
# (57999996, 43, 114, 0)
# timestamp 57999996
# ascissa 43
# ordinata 114
# polarity 0
# (57899997, 195, 143, 0)
# timestamp 57899997
# ascissa 195
# ordinata 143
# polarity 0
# (57799997, 269, 140, 1)
# timestamp 57799997
# ascissa 269
# ordinata 140
# polarity 1
# (57699996, 282, 50, 0)
# timestamp 57699996
# ascissa 282
# ordinata 50
# polarity 0
# (57599997, 262, 88, 0)
# timestamp 57599997
# ascissa 262
# ordinata 88
# polarity 0
# (57499997, 47, 196, 1)
# timestamp 57499997
# ascissa 47
# ordinata 196
# polarity 1
# (57399997, 23, 158, 0)
# timestamp 57399997
# ascissa 23
# ordinata 158
# polarity 0
# (57299997, 88, 196, 0)
# timestamp 57299997
# ascissa 88
# ordinata 196
# polarity 0
# (57199997, 250, 42, 0)
# timestamp 57199997
# ascissa 250
# ordinata 42
# polarity 0
# (57099997, 297, 124, 0)
# timestamp 57099997
# ascissa 297
# ordinata 124
# polarity 0
# (56999997, 31, 81, 1)
# timestamp 56999997
# ascissa 31
# ordinata 81
# polarity 1
# (56899997, 13, 52, 0)
# timestamp 56899997
# ascissa 13
# ordinata 52
# polarity 0
# (56799997, 231, 152, 1)
# timestamp 56799997
# ascissa 231
# ordinata 152
# polarity 1
# (56699997, 20, 54, 0)
# timestamp 56699997
# ascissa 20
# ordinata 54
# polarity 0
# (56599996, 6, 133, 1)
# timestamp 56599996
# ascissa 6
# ordinata 133
# polarity 1
# (56499996, 292, 191, 1)
# timestamp 56499996
# ascissa 292
# ordinata 191
# polarity 1
# (56399997, 277, 181, 0)
# timestamp 56399997
# ascissa 277
# ordinata 181
# polarity 0
# (56299995, 272, 118, 0)
# timestamp 56299995
# ascissa 272
# ordinata 118
# polarity 0
# (56199993, 247, 126, 0)
# timestamp 56199993
# ascissa 247
# ordinata 126
# polarity 0
# (56099997, 290, 28, 0)
# timestamp 56099997
# ascissa 290
# ordinata 28
# polarity 0
# (55999997, 268, 165, 1)
# timestamp 55999997
# ascissa 268
# ordinata 165
# polarity 1
# (55899997, 231, 75, 1)
# timestamp 55899997
# ascissa 231
# ordinata 75
# polarity 1
# (55799996, 287, 41, 0)
# timestamp 55799996
# ascissa 287
# ordinata 41
# polarity 0
# (55699997, 20, 158, 0)
# timestamp 55699997
# ascissa 20
# ordinata 158
# polarity 0
# (55599997, 276, 94, 1)
# timestamp 55599997
# ascissa 276
# ordinata 94
# polarity 1
# (55499995, 299, 48, 0)
# timestamp 55499995
# ascissa 299
# ordinata 48
# polarity 0
# (55399997, 298, 138, 0)
# timestamp 55399997
# ascissa 298
# ordinata 138
# polarity 0
# (55299991, 299, 188, 0)
# timestamp 55299991
# ascissa 299
# ordinata 188
# polarity 0
# (55199997, 268, 157, 0)
# timestamp 55199997
# ascissa 268
# ordinata 157
# polarity 0
# (55099997, 218, 147, 0)
# timestamp 55099997
# ascissa 218
# ordinata 147
# polarity 0
# (54999997, 6, 49, 0)
# timestamp 54999997
# ascissa 6
# ordinata 49
# polarity 0
# (54899997, 291, 168, 1)
# timestamp 54899997
# ascissa 291
# ordinata 168
# polarity 1
# (54799997, 6, 44, 1)
# timestamp 54799997
# ascissa 6
# ordinata 44
# polarity 1
# (54699997, 96, 216, 1)
# timestamp 54699997
# ascissa 96
# ordinata 216
# polarity 1
# (54599997, 9, 46, 0)
# timestamp 54599997
# ascissa 9
# ordinata 46
# polarity 0
# (54499997, 3, 27, 0)
# timestamp 54499997
# ascissa 3
# ordinata 27
# polarity 0
# (54399997, 67, 30, 0)
# timestamp 54399997
# ascissa 67
# ordinata 30
# polarity 0
# (54299997, 215, 138, 1)
# timestamp 54299997
# ascissa 215
# ordinata 138
# polarity 1
# (54199997, 0, 193, 1)
# timestamp 54199997
# ascissa 0
# ordinata 193
# polarity 1
# (54099997, 117, 190, 0)
# timestamp 54099997
# ascissa 117
# ordinata 190
# polarity 0
# (53999997, 246, 207, 0)
# timestamp 53999997
# ascissa 246
# ordinata 207
# polarity 0
# (53899997, 51, 83, 1)
# timestamp 53899997
# ascissa 51
# ordinata 83
# polarity 1
# (53799997, 20, 147, 0)
# timestamp 53799997
# ascissa 20
# ordinata 147
# polarity 0
# (53699997, 76, 49, 1)
# timestamp 53699997
# ascissa 76
# ordinata 49
# polarity 1
# (53599997, 36, 35, 1)
# timestamp 53599997
# ascissa 36
# ordinata 35
# polarity 1
# (53499997, 153, 204, 1)
# timestamp 53499997
# ascissa 153
# ordinata 204
# polarity 1
# (53399997, 258, 191, 1)
# timestamp 53399997
# ascissa 258
# ordinata 191
# polarity 1
# (53299997, 261, 213, 0)
# timestamp 53299997
# ascissa 261
# ordinata 213
# polarity 0
# (53199997, 220, 169, 1)
# timestamp 53199997
# ascissa 220
# ordinata 169
# polarity 1
# (53099997, 163, 147, 1)
# timestamp 53099997
# ascissa 163
# ordinata 147
# polarity 1
# (52999997, 99, 16, 1)
# timestamp 52999997
# ascissa 99
# ordinata 16
# polarity 1
# (52899997, 112, 79, 0)
# timestamp 52899997
# ascissa 112
# ordinata 79
# polarity 0
# (52799997, 64, 237, 0)
# timestamp 52799997
# ascissa 64
# ordinata 237
# polarity 0
# (52699997, 167, 139, 0)
# timestamp 52699997
# ascissa 167
# ordinata 139
# polarity 0
# (52599997, 129, 43, 0)
# timestamp 52599997
# ascissa 129
# ordinata 43
# polarity 0
# (52499997, 133, 38, 0)
# timestamp 52499997
# ascissa 133
# ordinata 38
# polarity 0
# (52399997, 106, 65, 1)
# timestamp 52399997
# ascissa 106
# ordinata 65
# polarity 1
# (52299997, 3, 205, 0)
# timestamp 52299997
# ascissa 3
# ordinata 205
# polarity 0
# (52199997, 169, 185, 0)
# timestamp 52199997
# ascissa 169
# ordinata 185
# polarity 0
# (52099997, 71, 51, 1)
# timestamp 52099997
# ascissa 71
# ordinata 51
# polarity 1
# (51999997, 116, 64, 1)
# timestamp 51999997
# ascissa 116
# ordinata 64
# polarity 1
# (51899997, 51, 83, 0)
# timestamp 51899997
# ascissa 51
# ordinata 83
# polarity 0
# (51799997, 226, 132, 1)
# timestamp 51799997
# ascissa 226
# ordinata 132
# polarity 1
# (51699997, 123, 93, 1)
# timestamp 51699997
# ascissa 123
# ordinata 93
# polarity 1
# (51599997, 278, 5, 0)
# timestamp 51599997
# ascissa 278
# ordinata 5
# polarity 0
# (51499997, 290, 96, 1)
# timestamp 51499997
# ascissa 290
# ordinata 96
# polarity 1
# (51399997, 181, 135, 1)
# timestamp 51399997
# ascissa 181
# ordinata 135
# polarity 1
# (51299997, 141, 119, 0)
# timestamp 51299997
# ascissa 141
# ordinata 119
# polarity 0
# (51199997, 273, 69, 1)
# timestamp 51199997
# ascissa 273
# ordinata 69
# polarity 1
# (51099997, 3, 59, 1)
# timestamp 51099997
# ascissa 3
# ordinata 59
# polarity 1
# (50999997, 64, 21, 0)
# timestamp 50999997
# ascissa 64
# ordinata 21
# polarity 0
# (50899997, 86, 137, 0)
# timestamp 50899997
# ascissa 86
# ordinata 137
# polarity 0
# (50799997, 239, 136, 0)
# timestamp 50799997
# ascissa 239
# ordinata 136
# polarity 0
# (50699997, 232, 130, 0)
# timestamp 50699997
# ascissa 232
# ordinata 130
# polarity 0
# (50599997, 302, 144, 1)
# timestamp 50599997
# ascissa 302
# ordinata 144
# polarity 1
# (50499997, 221, 107, 1)
# timestamp 50499997
# ascissa 221
# ordinata 107
# polarity 1
# (50399997, 269, 215, 0)
# timestamp 50399997
# ascissa 269
# ordinata 215
# polarity 0
# (50299997, 32, 79, 0)
# timestamp 50299997
# ascissa 32
# ordinata 79
# polarity 0
# (50199997, 274, 150, 0)
# timestamp 50199997
# ascissa 274
# ordinata 150
# polarity 0
# (50099997, 157, 148, 0)
# timestamp 50099997
# ascissa 157
# ordinata 148
# polarity 0
# (49999996, 32, 0, 1)
# timestamp 49999996
# ascissa 32
# ordinata 0
# polarity 1
# (49899996, 59, 206, 0)
# timestamp 49899996
# ascissa 59
# ordinata 206
# polarity 0
# (49799996, 241, 192, 0)
# timestamp 49799996
# ascissa 241
# ordinata 192
# polarity 0
# (49699997, 16, 190, 0)
# timestamp 49699997
# ascissa 16
# ordinata 190
# polarity 0
# (49599997, 242, 153, 1)
# timestamp 49599997
# ascissa 242
# ordinata 153
# polarity 1
# (49499997, 158, 141, 1)
# timestamp 49499997
# ascissa 158
# ordinata 141
# polarity 1
# (49399996, 56, 122, 0)
# timestamp 49399996
# ascissa 56
# ordinata 122
# polarity 0
# (49299997, 118, 52, 0)
# timestamp 49299997
# ascissa 118
# ordinata 52
# polarity 0
# (49199997, 48, 162, 0)
# timestamp 49199997
# ascissa 48
# ordinata 162
# polarity 0
# (49099997, 52, 34, 0)
# timestamp 49099997
# ascissa 52
# ordinata 34
# polarity 0
# (48999997, 84, 92, 0)
# timestamp 48999997
# ascissa 84
# ordinata 92
# polarity 0
# (48899997, 263, 145, 1)
# timestamp 48899997
# ascissa 263
# ordinata 145
# polarity 1
# (48799997, 4, 196, 0)
# timestamp 48799997
# ascissa 4
# ordinata 196
# polarity 0
# (48699997, 19, 2, 0)
# timestamp 48699997
# ascissa 19
# ordinata 2
# polarity 0
# (48599994, 148, 138, 1)
# timestamp 48599994
# ascissa 148
# ordinata 138
# polarity 1
# (48499994, 19, 82, 0)
# timestamp 48499994
# ascissa 19
# ordinata 82
# polarity 0
# (48399997, 38, 13, 0)
# timestamp 48399997
# ascissa 38
# ordinata 13
# polarity 0
# (48299997, 239, 40, 0)
# timestamp 48299997
# ascissa 239
# ordinata 40
# polarity 0
# (48199989, 115, 80, 1)
# timestamp 48199989
# ascissa 115
# ordinata 80
# polarity 1
# (48099995, 55, 123, 0)
# timestamp 48099995
# ascissa 55
# ordinata 123
# polarity 0
# (47999994, 75, 81, 1)
# timestamp 47999994
# ascissa 75
# ordinata 81
# polarity 1
# (47899991, 284, 146, 0)
# timestamp 47899991
# ascissa 284
# ordinata 146
# polarity 0
# (47799997, 191, 129, 0)
# timestamp 47799997
# ascissa 191
# ordinata 129
# polarity 0
# (47699997, 275, 150, 0)
# timestamp 47699997
# ascissa 275
# ordinata 150
# polarity 0
# (47599996, 240, 84, 0)
# timestamp 47599996
# ascissa 240
# ordinata 84
# polarity 0
# (47499997, 17, 145, 1)
# timestamp 47499997
# ascissa 17
# ordinata 145
# polarity 1
# (47399995, 58, 113, 1)
# timestamp 47399995
# ascissa 58
# ordinata 113
# polarity 1
# (47299989, 166, 136, 1)
# timestamp 47299989
# ascissa 166
# ordinata 136
# polarity 1
# (47199995, 189, 134, 1)
# timestamp 47199995
# ascissa 189
# ordinata 134
# polarity 1
# (47099997, 291, 162, 1)
# timestamp 47099997
# ascissa 291
# ordinata 162
# polarity 1
# (46999983, 303, 146, 1)
# timestamp 46999983
# ascissa 303
# ordinata 146
# polarity 1
# (46899997, 288, 186, 1)
# timestamp 46899997
# ascissa 288
# ordinata 186
# polarity 1
# (46799997, 252, 157, 1)
# timestamp 46799997
# ascissa 252
# ordinata 157
# polarity 1
# (46699997, 87, 90, 1)
# timestamp 46699997
# ascissa 87
# ordinata 90
# polarity 1
# (46599997, 152, 144, 0)
# timestamp 46599997
# ascissa 152
# ordinata 144
# polarity 0
# (46499997, 286, 70, 0)
# timestamp 46499997
# ascissa 286
# ordinata 70
# polarity 0
# (46399997, 154, 194, 0)
# timestamp 46399997
# ascissa 154
# ordinata 194
# polarity 0
# (46299997, 282, 69, 1)
# timestamp 46299997
# ascissa 282
# ordinata 69
# polarity 1
# (46199997, 28, 164, 0)
# timestamp 46199997
# ascissa 28
# ordinata 164
# polarity 0
# (46099997, 40, 209, 1)
# timestamp 46099997
# ascissa 40
# ordinata 209
# polarity 1
# (45999995, 40, 128, 1)
# timestamp 45999995
# ascissa 40
# ordinata 128
# polarity 1
# (45899997, 203, 208, 0)
# timestamp 45899997
# ascissa 203
# ordinata 208
# polarity 0
# (45799995, 227, 121, 0)
# timestamp 45799995
# ascissa 227
# ordinata 121
# polarity 0
# (45699997, 67, 191, 1)
# timestamp 45699997
# ascissa 67
# ordinata 191
# polarity 1
# (45599997, 40, 15, 0)
# timestamp 45599997
# ascissa 40
# ordinata 15
# polarity 0
# (45499997, 161, 237, 0)
# timestamp 45499997
# ascissa 161
# ordinata 237
# polarity 0
# (45399997, 14, 229, 0)
# timestamp 45399997
# ascissa 14
# ordinata 229
# polarity 0
# (45299997, 12, 0, 0)
# timestamp 45299997
# ascissa 12
# ordinata 0
# polarity 0
# (45199997, 41, 106, 1)
# timestamp 45199997
# ascissa 41
# ordinata 106
# polarity 1
# (45099997, 293, 45, 1)
# timestamp 45099997
# ascissa 293
# ordinata 45
# polarity 1
# (44999997, 46, 85, 1)
# timestamp 44999997
# ascissa 46
# ordinata 85
# polarity 1
# (44899997, 281, 73, 1)
# timestamp 44899997
# ascissa 281
# ordinata 73
# polarity 1
# (44799997, 276, 60, 1)
# timestamp 44799997
# ascissa 276
# ordinata 60
# polarity 1
# (44699997, 70, 89, 1)
# timestamp 44699997
# ascissa 70
# ordinata 89
# polarity 1
# (44599996, 110, 58, 0)
# timestamp 44599996
# ascissa 110
# ordinata 58
# polarity 0
# (44499997, 94, 136, 0)
# timestamp 44499997
# ascissa 94
# ordinata 136
# polarity 0
# (44399996, 273, 162, 0)
# timestamp 44399996
# ascissa 273
# ordinata 162
# polarity 0
# (44299997, 62, 24, 0)
# timestamp 44299997
# ascissa 62
# ordinata 24
# polarity 0
# (44199997, 1, 66, 1)
# timestamp 44199997
# ascissa 1
# ordinata 66
# polarity 1
# (44099997, 17, 163, 0)
# timestamp 44099997
# ascissa 17
# ordinata 163
# polarity 0
# (43999997, 270, 156, 0)
# timestamp 43999997
# ascissa 270
# ordinata 156
# polarity 0
# (43899997, 289, 209, 1)
# timestamp 43899997
# ascissa 289
# ordinata 209
# polarity 1
# (43799997, 266, 140, 0)
# timestamp 43799997
# ascissa 266
# ordinata 140
# polarity 0
# (43699997, 277, 67, 0)
# timestamp 43699997
# ascissa 277
# ordinata 67
# polarity 0
# (43599997, 258, 199, 0)
# timestamp 43599997
# ascissa 258
# ordinata 199
# polarity 0
# (43499997, 278, 161, 1)
# timestamp 43499997
# ascissa 278
# ordinata 161
# polarity 1
# (43399997, 293, 96, 0)
# timestamp 43399997
# ascissa 293
# ordinata 96
# polarity 0
# (43299997, 60, 95, 0)
# timestamp 43299997
# ascissa 60
# ordinata 95
# polarity 0
# (43199992, 120, 110, 1)
# timestamp 43199992
# ascissa 120
# ordinata 110
# polarity 1
# (43099996, 81, 135, 0)
# timestamp 43099996
# ascissa 81
# ordinata 135
# polarity 0
# (42999985, 71, 86, 0)
# timestamp 42999985
# ascissa 71
# ordinata 86
# polarity 0
# (42899996, 143, 152, 0)
# timestamp 42899996
# ascissa 143
# ordinata 152
# polarity 0
# (42799997, 194, 161, 0)
# timestamp 42799997
# ascissa 194
# ordinata 161
# polarity 0
# (42699997, 295, 152, 1)
# timestamp 42699997
# ascissa 295
# ordinata 152
# polarity 1
# (42599997, 267, 184, 0)
# timestamp 42599997
# ascissa 267
# ordinata 184
# polarity 0
# (42499997, 292, 103, 0)
# timestamp 42499997
# ascissa 292
# ordinata 103
# polarity 0
# (42399997, 289, 112, 1)
# timestamp 42399997
# ascissa 289
# ordinata 112
# polarity 1
# (42299997, 262, 27, 1)
# timestamp 42299997
# ascissa 262
# ordinata 27
# polarity 1
# (42199997, 75, 88, 0)
# timestamp 42199997
# ascissa 75
# ordinata 88
# polarity 0
# (42099997, 289, 146, 0)
# timestamp 42099997
# ascissa 289
# ordinata 146
# polarity 0
# (41999997, 279, 34, 1)
# timestamp 41999997
# ascissa 279
# ordinata 34
# polarity 1
# (41899997, 255, 75, 0)
# timestamp 41899997
# ascissa 255
# ordinata 75
# polarity 0
# (41799996, 261, 177, 0)
# timestamp 41799996
# ascissa 261
# ordinata 177
# polarity 0
# (41699997, 236, 159, 1)
# timestamp 41699997
# ascissa 236
# ordinata 159
# polarity 1
# (41599997, 239, 58, 1)
# timestamp 41599997
# ascissa 239
# ordinata 58
# polarity 1
# (41499997, 242, 183, 0)
# timestamp 41499997
# ascissa 242
# ordinata 183
# polarity 0
# (41399997, 239, 93, 1)
# timestamp 41399997
# ascissa 239
# ordinata 93
# polarity 1
# (41299997, 18, 35, 0)
# timestamp 41299997
# ascissa 18
# ordinata 35
# polarity 0
# (41199997, 295, 169, 1)
# timestamp 41199997
# ascissa 295
# ordinata 169
# polarity 1
# (41099997, 301, 191, 0)
# timestamp 41099997
# ascissa 301
# ordinata 191
# polarity 0
# (40999997, 206, 148, 0)
# timestamp 40999997
# ascissa 206
# ordinata 148
# polarity 0
# (40899996, 271, 166, 0)
# timestamp 40899996
# ascissa 271
# ordinata 166
# polarity 0
# (40799997, 7, 37, 0)
# timestamp 40799997
# ascissa 7
# ordinata 37
# polarity 0
# (40699997, 241, 144, 1)
# timestamp 40699997
# ascissa 241
# ordinata 144
# polarity 1
# (40599997, 44, 59, 0)
# timestamp 40599997
# ascissa 44
# ordinata 59
# polarity 0
# (40499997, 178, 149, 0)
# timestamp 40499997
# ascissa 178
# ordinata 149
# polarity 0
# (40399997, 8, 24, 0)
# timestamp 40399997
# ascissa 8
# ordinata 24
# polarity 0
# (40299997, 164, 133, 0)
# timestamp 40299997
# ascissa 164
# ordinata 133
# polarity 0
# (40199997, 10, 77, 0)
# timestamp 40199997
# ascissa 10
# ordinata 77
# polarity 0
# (40099997, 110, 115, 0)
# timestamp 40099997
# ascissa 110
# ordinata 115
# polarity 0
# (39999997, 33, 26, 1)
# timestamp 39999997
# ascissa 33
# ordinata 26
# polarity 1
# (39899997, 100, 120, 1)
# timestamp 39899997
# ascissa 100
# ordinata 120
# polarity 1
# (39799997, 85, 78, 1)
# timestamp 39799997
# ascissa 85
# ordinata 78
# polarity 1
# (39699996, 17, 39, 0)
# timestamp 39699996
# ascissa 17
# ordinata 39
# polarity 0
# (39599997, 21, 142, 0)
# timestamp 39599997
# ascissa 21
# ordinata 142
# polarity 0
# (39499997, 97, 81, 1)
# timestamp 39499997
# ascissa 97
# ordinata 81
# polarity 1
# (39399997, 108, 161, 0)
# timestamp 39399997
# ascissa 108
# ordinata 161
# polarity 0
# (39299997, 245, 54, 0)
# timestamp 39299997
# ascissa 245
# ordinata 54
# polarity 0
# (39199997, 14, 199, 0)
# timestamp 39199997
# ascissa 14
# ordinata 199
# polarity 0
# (39099997, 7, 9, 0)
# timestamp 39099997
# ascissa 7
# ordinata 9
# polarity 0
# (38999997, 286, 61, 1)
# timestamp 38999997
# ascissa 286
# ordinata 61
# polarity 1
# (38899997, 14, 53, 0)
# timestamp 38899997
# ascissa 14
# ordinata 53
# polarity 0
# (38799997, 288, 94, 0)
# timestamp 38799997
# ascissa 288
# ordinata 94
# polarity 0
# (38699997, 259, 138, 0)
# timestamp 38699997
# ascissa 259
# ordinata 138
# polarity 0
# (38599997, 8, 215, 1)
# timestamp 38599997
# ascissa 8
# ordinata 215
# polarity 1
# (38499997, 300, 29, 0)
# timestamp 38499997
# ascissa 300
# ordinata 29
# polarity 0
# (38399997, 296, 41, 0)
# timestamp 38399997
# ascissa 296
# ordinata 41
# polarity 0
# (38299996, 279, 17, 0)
# timestamp 38299996
# ascissa 279
# ordinata 17
# polarity 0
# (38199997, 235, 93, 0)
# timestamp 38199997
# ascissa 235
# ordinata 93
# polarity 0
# (38099996, 235, 11, 0)
# timestamp 38099996
# ascissa 235
# ordinata 11
# polarity 0
# (37999997, 250, 76, 1)
# timestamp 37999997
# ascissa 250
# ordinata 76
# polarity 1
# (37899997, 219, 157, 1)
# timestamp 37899997
# ascissa 219
# ordinata 157
# polarity 1
# (37799997, 257, 29, 0)
# timestamp 37799997
# ascissa 257
# ordinata 29
# polarity 0
# (37699997, 199, 28, 0)
# timestamp 37699997
# ascissa 199
# ordinata 28
# polarity 0
# (37599997, 242, 20, 0)
# timestamp 37599997
# ascissa 242
# ordinata 20
# polarity 0
# (37499997, 13, 74, 1)
# timestamp 37499997
# ascissa 13
# ordinata 74
# polarity 1
# (37399997, 215, 71, 0)
# timestamp 37399997
# ascissa 215
# ordinata 71
# polarity 0
# (37299997, 8, 12, 0)
# timestamp 37299997
# ascissa 8
# ordinata 12
# polarity 0
# (37199997, 289, 193, 0)
# timestamp 37199997
# ascissa 289
# ordinata 193
# polarity 0
# (37099997, 260, 163, 0)
# timestamp 37099997
# ascissa 260
# ordinata 163
# polarity 0
# (36999997, 37, 18, 1)
# timestamp 36999997
# ascissa 37
# ordinata 18
# polarity 1
# (36899997, 230, 85, 0)
# timestamp 36899997
# ascissa 230
# ordinata 85
# polarity 0
# (36799997, 268, 170, 0)
# timestamp 36799997
# ascissa 268
# ordinata 170
# polarity 0
# (36699997, 294, 133, 1)
# timestamp 36699997
# ascissa 294
# ordinata 133
# polarity 1
# (36599997, 264, 164, 0)
# timestamp 36599997
# ascissa 264
# ordinata 164
# polarity 0
# (36499996, 300, 67, 1)
# timestamp 36499996
# ascissa 300
# ordinata 67
# polarity 1
# (36399997, 246, 210, 0)
# timestamp 36399997
# ascissa 246
# ordinata 210
# polarity 0
# (36299997, 59, 64, 0)
# timestamp 36299997
# ascissa 59
# ordinata 64
# polarity 0
# (36199991, 276, 133, 1)
# timestamp 36199991
# ascissa 276
# ordinata 133
# polarity 1
# (36099997, 75, 23, 1)
# timestamp 36099997
# ascissa 75
# ordinata 23
# polarity 1
# (35999997, 256, 180, 1)
# timestamp 35999997
# ascissa 256
# ordinata 180
# polarity 1
# (35899997, 81, 60, 1)
# timestamp 35899997
# ascissa 81
# ordinata 60
# polarity 1
# (35799996, 263, 147, 0)
# timestamp 35799996
# ascissa 263
# ordinata 147
# polarity 0
# (35699996, 206, 88, 1)
# timestamp 35699996
# ascissa 206
# ordinata 88
# polarity 1
# (35599993, 297, 87, 1)
# timestamp 35599993
# ascissa 297
# ordinata 87
# polarity 1
# (35499997, 41, 172, 1)
# timestamp 35499997
# ascissa 41
# ordinata 172
# polarity 1
# (35399997, 205, 91, 0)
# timestamp 35399997
# ascissa 205
# ordinata 91
# polarity 0
# (35299997, 298, 197, 0)
# timestamp 35299997
# ascissa 298
# ordinata 197
# polarity 0
# (35199997, 103, 80, 1)
# timestamp 35199997
# ascissa 103
# ordinata 80
# polarity 1
# (35099997, 245, 41, 0)
# timestamp 35099997
# ascissa 245
# ordinata 41
# polarity 0
# (34999997, 259, 124, 0)
# timestamp 34999997
# ascissa 259
# ordinata 124
# polarity 0
# (34899996, 208, 95, 0)
# timestamp 34899996
# ascissa 208
# ordinata 95
# polarity 0
# (34799997, 111, 75, 1)
# timestamp 34799997
# ascissa 111
# ordinata 75
# polarity 1
# (34699997, 75, 133, 0)
# timestamp 34699997
# ascissa 75
# ordinata 133
# polarity 0
# (34599997, 9, 204, 0)
# timestamp 34599997
# ascissa 9
# ordinata 204
# polarity 0
# (34499997, 297, 184, 0)
# timestamp 34499997
# ascissa 297
# ordinata 184
# polarity 0
# (34399996, 58, 204, 1)
# timestamp 34399996
# ascissa 58
# ordinata 204
# polarity 1
# (34299997, 277, 160, 1)
# timestamp 34299997
# ascissa 277
# ordinata 160
# polarity 1
# (34199997, 262, 202, 0)
# timestamp 34199997
# ascissa 262
# ordinata 202
# polarity 0
# (34099997, 35, 34, 0)
# timestamp 34099997
# ascissa 35
# ordinata 34
# polarity 0
# (33999997, 86, 123, 0)
# timestamp 33999997
# ascissa 86
# ordinata 123
# polarity 0
# (33899997, 269, 78, 1)
# timestamp 33899997
# ascissa 269
# ordinata 78
# polarity 1
# (33799996, 290, 130, 0)
# timestamp 33799996
# ascissa 290
# ordinata 130
# polarity 0
# (33699997, 6, 2, 0)
# timestamp 33699997
# ascissa 6
# ordinata 2
# polarity 0
# (33599997, 39, 32, 1)
# timestamp 33599997
# ascissa 39
# ordinata 32
# polarity 1
# (33499997, 194, 136, 0)
# timestamp 33499997
# ascissa 194
# ordinata 136
# polarity 0
# (33399997, 217, 171, 1)
# timestamp 33399997
# ascissa 217
# ordinata 171
# polarity 1
# (33299996, 229, 86, 0)
# timestamp 33299996
# ascissa 229
# ordinata 86
# polarity 0
# (33199997, 290, 129, 0)
# timestamp 33199997
# ascissa 290
# ordinata 129
# polarity 0
# (33099997, 125, 222, 0)
# timestamp 33099997
# ascissa 125
# ordinata 222
# polarity 0
# (32999997, 81, 29, 1)
# timestamp 32999997
# ascissa 81
# ordinata 29
# polarity 1
# (32899997, 20, 80, 0)
# timestamp 32899997
# ascissa 20
# ordinata 80
# polarity 0
# (32799996, 25, 190, 0)
# timestamp 32799996
# ascissa 25
# ordinata 190
# polarity 0
# (32699997, 76, 70, 0)
# timestamp 32699997
# ascissa 76
# ordinata 70
# polarity 0
# (32599997, 65, 58, 1)
# timestamp 32599997
# ascissa 65
# ordinata 58
# polarity 1
# (32499997, 72, 149, 1)
# timestamp 32499997
# ascissa 72
# ordinata 149
# polarity 1
# (32399996, 192, 188, 0)
# timestamp 32399996
# ascissa 192
# ordinata 188
# polarity 0
# (32299996, 290, 97, 0)
# timestamp 32299996
# ascissa 290
# ordinata 97
# polarity 0
# (32199995, 155, 197, 0)
# timestamp 32199995
# ascissa 155
# ordinata 197
# polarity 0
# (32099997, 294, 217, 0)
# timestamp 32099997
# ascissa 294
# ordinata 217
# polarity 0
# (31999997, 274, 174, 0)
# timestamp 31999997
# ascissa 274
# ordinata 174
# polarity 0
# (31899995, 264, 50, 0)
# timestamp 31899995
# ascissa 264
# ordinata 50
# polarity 0
# (31799997, 155, 183, 0)
# timestamp 31799997
# ascissa 155
# ordinata 183
# polarity 0
# (31699997, 267, 210, 1)
# timestamp 31699997
# ascissa 267
# ordinata 210
# polarity 1
# (31599993, 270, 147, 1)
# timestamp 31599993
# ascissa 270
# ordinata 147
# polarity 1
# (31499997, 145, 125, 0)
# timestamp 31499997
# ascissa 145
# ordinata 125
# polarity 0
# (31399992, 270, 198, 0)
# timestamp 31399992
# ascissa 270
# ordinata 198
# polarity 0
# (31299997, 220, 167, 0)
# timestamp 31299997
# ascissa 220
# ordinata 167
# polarity 0
# (31199997, 294, 194, 0)
# timestamp 31199997
# ascissa 294
# ordinata 194
# polarity 0
# (31099996, 291, 97, 0)
# timestamp 31099996
# ascissa 291
# ordinata 97
# polarity 0
# (30999997, 288, 141, 0)
# timestamp 30999997
# ascissa 288
# ordinata 141
# polarity 0
# (30899997, 88, 95, 0)
# timestamp 30899997
# ascissa 88
# ordinata 95
# polarity 0
# (30799996, 271, 64, 0)
# timestamp 30799996
# ascissa 271
# ordinata 64
# polarity 0
# (30699995, 297, 126, 0)
# timestamp 30699995
# ascissa 297
# ordinata 126
# polarity 0
# (30599979, 45, 95, 0)
# timestamp 30599979
# ascissa 45
# ordinata 95
# polarity 0
# (30499992, 299, 120, 0)
# timestamp 30499992
# ascissa 299
# ordinata 120
# polarity 0
# (30399993, 25, 91, 0)
# timestamp 30399993
# ascissa 25
# ordinata 91
# polarity 0
# (30299988, 48, 106, 1)
# timestamp 30299988
# ascissa 48
# ordinata 106
# polarity 1
# (30199992, 281, 82, 1)
# timestamp 30199992
# ascissa 281
# ordinata 82
# polarity 1
# (30099991, 258, 36, 1)
# timestamp 30099991
# ascissa 258
# ordinata 36
# polarity 1
# (29999997, 294, 61, 1)
# timestamp 29999997
# ascissa 294
# ordinata 61
# polarity 1
# (29899992, 62, 89, 0)
# timestamp 29899992
# ascissa 62
# ordinata 89
# polarity 0
# (29799979, 95, 157, 0)
# timestamp 29799979
# ascissa 95
# ordinata 157
# polarity 0
# (29699995, 282, 28, 1)
# timestamp 29699995
# ascissa 282
# ordinata 28
# polarity 1
# (29599948, 14, 54, 1)
# timestamp 29599948
# ascissa 14
# ordinata 54
# polarity 1
# (29499994, 287, 30, 1)
# timestamp 29499994
# ascissa 287
# ordinata 30
# polarity 1
# (29399990, 249, 96, 1)
# timestamp 29399990
# ascissa 249
# ordinata 96
# polarity 1
# (29299994, 242, 124, 0)
# timestamp 29299994
# ascissa 242
# ordinata 124
# polarity 0
# (29199975, 203, 128, 0)
# timestamp 29199975
# ascissa 203
# ordinata 128
# polarity 0
# (29099986, 282, 15, 0)
# timestamp 29099986
# ascissa 282
# ordinata 15
# polarity 0
# (28999997, 75, 154, 0)
# timestamp 28999997
# ascissa 75
# ordinata 154
# polarity 0
# (28899997, 258, 123, 0)
# timestamp 28899997
# ascissa 258
# ordinata 123
# polarity 0
# (28799981, 63, 88, 1)
# timestamp 28799981
# ascissa 63
# ordinata 88
# polarity 1
# (28699997, 202, 147, 1)
# timestamp 28699997
# ascissa 202
# ordinata 147
# polarity 1
# (28599993, 16, 190, 0)
# timestamp 28599993
# ascissa 16
# ordinata 190
# polarity 0
# (28499967, 32, 169, 0)
# timestamp 28499967
# ascissa 32
# ordinata 169
# polarity 0
# (28399948, 3, 173, 0)
# timestamp 28399948
# ascissa 3
# ordinata 173
# polarity 0
# (28299993, 83, 163, 0)
# timestamp 28299993
# ascissa 83
# ordinata 163
# polarity 0
# (28199989, 274, 93, 0)
# timestamp 28199989
# ascissa 274
# ordinata 93
# polarity 0
# (28099985, 292, 106, 1)
# timestamp 28099985
# ascissa 292
# ordinata 106
# polarity 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\paolo\OneDrive\Desktop\Progetti VSCode\Progetto_computer_vision\tutorial.ipynb Cell 16 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/paolo/OneDrive/Desktop/Progetti%20VSCode/Progetto_computer_vision/tutorial.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> # they should be sorted in descending timestamp order !
#       <a href='vscode-notebook-cell:/c%3A/Users/paolo/OneDrive/Desktop/Progetti%20VSCode/Progetto_computer_vision/tutorial.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> events = events[::-1]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paolo/OneDrive/Desktop/Progetti%20VSCode/Progetto_computer_vision/tutorial.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> print(events[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/paolo/OneDrive/Desktop/Progetti%20VSCode/Progetto_computer_vision/tutorial.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> print('timestamp', events[0]['t'])
#      <a href='vscode-notebook-cell:/c%3A/Users/paolo/OneDrive/Desktop/Progetti%20VSCode/Progetto_computer_vision/tutorial.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> print('ascissa', events[0]['x'])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
